# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#training dataset
df_tdata=pd.read_csv("C:\\Users\\chara\\Downloads\\Training Data.csv")
df_tdata.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df_tdata.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
df_tdata['Gender'] = df_tdata['Gender'].fillna(df_tdata['Gender'].dropna().mode().values[0] )
df_tdata['Married'] = df_tdata['Married'].fillna(df_tdata['Married'].dropna().mode().values[0] )
df_tdata['Dependents'] = df_tdata['Dependents'].fillna(df_tdata['Dependents'].dropna().mode().values[0] )
df_tdata['Self_Employed'] = df_tdata['Self_Employed'].fillna(df_tdata['Self_Employed'].dropna().mode().values[0] )
df_tdata['LoanAmount'] =  df_tdata['LoanAmount'].fillna(df_tdata['LoanAmount'].dropna().median() )
df_tdata['Loan_Amount_Term'] = df_tdata['Loan_Amount_Term'].fillna(df_tdata['Loan_Amount_Term'].dropna().mode().values[0] )
df_tdata['Credit_History'] = df_tdata['Credit_History'].fillna(df_tdata['Credit_History'].dropna().mode().values[0] )['Married'] = df_tdata['Married'].fillna(
df_tdata['Married'].dropna().mode().values[0] )
df_tdata['Dependents'] = df_tdata['Dependents'].fillna(df_tdata['Dependents'].dropna().mode().values[0] )
df_tdata['Self_Employed'] = df_tdata['Self_Employed'].fillna(df_tdata['Self_Employed'].dropna().mode().values[0] )
df_tdata['LoanAmount'] = df_tdata['LoanAmount'].fillna(df_tdata['LoanAmount'].dropna().median() )
df_tdata['Loan_Amount_Term'] =df_tdata['Loan_Amount_Term'].fillna(df_tdata['Loan_Amount_Term'].dropna().mode().values[0] )
df_tdata['Credit_History'] = df_tdata['Credit_History'].fillna(df_tdata['Credit_History'].dropna().mode().values[0] )

# %%
df_tdata.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False       False             False
# ...

# %%
#7 answer
#highest income specification n info about the applicant
#8 answer
#feature selection
#9 answer
#model selection
#10 answer
#hyper parameter tuning
#11 answer
#actual vs predicted
#12 answer
#model accuracy
#13 answer
#accuracy improvement methods

# %%
df_tdata.Loan_Status=df_tdata.Loan_Status.map({'Y':1,'N':0})
df_tdata.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df_tdata.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  145.752443        342.410423
# std        6109.041673        2926.248369   84.107233         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  128.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Loan_Status
# count   614.000000
# mean      0.687296
# std       0.463973
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
#ratio of male to female
print("Number of null values : ", df_tdata['Gender'].isnull().sum())
print("Unique values : ", df_tdata['Gender'].unique())
print("Value counts : \n",df_tdata['Gender'].value_counts())
# Out:
# Number of null values :  0
# Unique values :  ['Male' 'Female']
# Value counts :
#  Male      502
# Female    112
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(6, 6))
sns.countplot(x = 'Gender', data = df_tdata)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#male married and non married
#female married and non married
print("Number of null values : ", df_tdata['Married'].isnull().sum())
print("Unique values : ", df_tdata['Married'].unique())
print("Value counts : \n",df_tdata['Married'].value_counts())
# Out:
# Number of null values :  0
# Unique values :  ['No' 'Yes']
# Value counts :
#  Yes    401
# No     213
# Name: Married, dtype: int64

# %%
#male and female graduated or non graduated
print("Number of null values : ", df_tdata['Education'].isnull().sum())
print("Unique values : ", df_tdata['Education'].unique())
print("Value counts : \n",df_tdata['Education'].value_counts())
# Out:
# Number of null values :  0
# Unique values :  ['Graduate' 'Not Graduate']
# Value counts :
#  Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
#type of encoding on education column-#ONE HOT ENCODING
df_tdata.Education=df_tdata.Education.map({'Graduate':1,'Not Graduate':0})
df_tdata.Education.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: Education, dtype: int64

# %%
#feature selection
print(" Columns in the Train Data : \n", df_tdata.columns)
# Out:
#  Columns in the Train Data :
#  Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df_tdata.drop('Loan_ID', axis = 1, inplace = True)
df_tdata.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#highest income specification n info about the applicant
df_tdata['ApplicantIncome'].max()
# Out:
# 81000

# %%
df_tdata[df_tdata['ApplicantIncome']==df_tdata['ApplicantIncome'].max()]
# Out:
#     Gender Married Dependents  Education Self_Employed  ApplicantIncome  \
# 409   Male     Yes         3+          1            No            81000
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Credit_History  \
# 409                0.0       360.0             360.0            Yes
#
#     Property_Area  Loan_Status
# 409         Rural            0

# %%
X = df_tdata.drop('Loan_Status',axis=1)
y = df_tdata['Loan_Status']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
df_tdata.Gender=df_tdata.Gender.map({'Male':1,'Female':0})
df_tdata.Married=df_tdata.Married.map({'Yes':1,'No':0})
df_tdata.Self_Employed=df_tdata.Self_Employed.map({'Yes':1,'No':0})
df_tdata.	Credit_History=df_tdata.Credit_History.map({'Yes':1,'No':0})
df_tdata.Property_Area=df_tdata.Property_Area.map({'Urban':1,'Rural':0})


df_tdata.Gender.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Gender, dtype: int64

# %%
df_tdata.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0             5849
# 1       1        1          1          1              0             4583
# 2       1        1          0          1              1             3000
# 3       1        1          0          0              0             2583
# 4       1        0          0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0               0
# 1             1508.0       128.0             360.0               1
# 2                0.0        66.0             360.0               1
# 3             2358.0       120.0             360.0               1
# 4                0.0       141.0             360.0               0
#
#    Property_Area  Loan_Status
# 0            1.0            1
# 1            0.0            0
# ...

# %%
#feature selection
y = df_tdata['Loan_Status']
X = df_tdata.drop('Loan_Status', axis = 1)

# %%
X['Property_Area']=X['Property_Area'].fillna(X['Property_Area'].mean())

# %%
from sklearn.tree import DecisionTreeClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
df_tdata['Dependents']=df_tdata['Dependents'].replace('3+',3)

# %%
df_tdata
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0          0          1              0             5849
# 1         1        1          1          1              0             4583
# 2         1        1          0          1              1             3000
# 3         1        1          0          0              0             2583
# 4         1        0          0          1              0             6000
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          1              0             2900
# 610       1        1          3          1              0             4106
# 611       1        1          1          1              0             8072
# 612       1        1          2          1              0             7583
# 613       0        0          0          1              1             4583
#
# ...

# %%
X_train.isna().any()
# Out:
# Gender               False
# Married              False
# Dependents           False
# Education            False
# Self_Employed        False
# ApplicantIncome      False
# CoapplicantIncome    False
# LoanAmount           False
# Loan_Amount_Term     False
# Credit_History       False
# Property_Area        False
# dtype: bool

# %%
from sklearn.metrics import f1_score
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
ypred_tree = tree.predict(X_test)

accuracy = f1_score(y_test, ypred_tree)
accuracy
# Out:
# 0.7252747252747253
